# %%
import os
import json
from bs4 import BeautifulSoup
import re

def extract_text_and_title_from_html(html_filepath):
    """
    从指定的 HTML 文件中提取标题和正文文本。
    """
    try:
        with open(html_filepath, 'r', encoding='utf-8') as f:
            html_content = f.read()

        soup = BeautifulSoup(html_content, 'lxml') 

        title_tag = soup.find('title')
        title_string = title_tag.string if title_tag else None
        title = title_string.strip() if title_string else os.path.basename(html_filepath)
        title = title.replace('.html', '')

        content_tag = soup.find('content') or soup.find('div', class_='rich_media_content') or \
                      soup.find('article') or soup.find('main') or soup.find('body')

        if content_tag:
            text = content_tag.get_text(separator='\n', strip=True)
            return title, text
        else:
            print(f"警告：在文件 {html_filepath} 中未找到明确的正文标签。")
            return title, None 

    except FileNotFoundError:
        print(f"错误：文件 {html_filepath} 未找到。")
        return None, None
    except Exception as e:
        print(f"处理文件 {html_filepath} 时出错: {e}")
        return None, None

def split_text(text, max_chunks=2, chunk_size=2000):
    """
    将文本分割成最多指定块数的块。
    """
    if not text:
        return []

    total_length = len(text)
    
    # 如果长度小于chunk_size，直接返回
    if total_length <= chunk_size:
        return [text.strip()]

    # 计算应分割的块数，最多为max_chunks
    desired_chunks = min(max_chunks, (total_length + chunk_size - 1) // chunk_size)

    chunks = []
    start = 0

    # 每块的 size 取决于总长和需要的块数
    step_size = total_length // desired_chunks

    for i in range(desired_chunks):
        end = start + step_size
        if i == desired_chunks - 1:  # 确保最后一块包含剩余文本
            end = total_length
        chunks.append(text[start:end].strip())
        start = end

    return [chunk for chunk in chunks if chunk]  # 只返回非空块

def contains_blocked_words(text, blocked_words):
    """
    检查文本中是否包含任意屏蔽词。
    """
    pattern = re.compile('|'.join(map(re.escape, blocked_words)))
    return bool(pattern.search(text))

# --- 配置 ---
html_directory = './data/html/' 
output_json_path = './data/processed_data.json' 
CHUNK_SIZE = 2000  # 每个文本块的目标大小（字符数）
BLOCKED_WORDS = ['阅读原文', '点点赞', '爱心', '广告', '推广', '推荐阅读', '此内容为.*', '点击这里', '更多信息', '访问网站', '公众号', '暖雪', '暖雪小屋']

# --- 主处理逻辑 ---
all_data_for_milvus = []
file_count = 0
chunk_count = 0

print(f"开始处理目录 '{html_directory}' 中的 HTML 文件...")

os.makedirs(os.path.dirname(output_json_path), exist_ok=True)

html_files = [f for f in os.listdir(html_directory) if f.endswith('.html')]
print(f"找到 {len(html_files)} 个 HTML 文件。")

for filename in html_files:
    filepath = os.path.join(html_directory, filename)
    file_count += 1

    title, main_text = extract_text_and_title_from_html(filepath)

    if main_text:
        # 获取合并后的文本块
        chunks = split_text(main_text, max_chunks=2, chunk_size=CHUNK_SIZE)

        # 过滤掉含有屏蔽词的块
        for i, chunk in enumerate(chunks):
            if not contains_blocked_words(chunk, BLOCKED_WORDS):
                chunk_count += 1
                milvus_entry = {
                    "id": f"{filename}_{i}", 
                    "title": title or filename, 
                    "abstract": chunk, 
                    "source_file": filename, 
                    "chunk_index": i
                }
                all_data_for_milvus.append(milvus_entry)
            # else:
                # print(f"    警告：块 {i} 含有屏蔽词，已跳过。")
    else:
        print(f"    警告：未能从 {filename} 提取有效文本内容。")

print(f"\n处理完成。共处理 {file_count} 个文件，生成 {chunk_count} 个文本块。")

# --- 保存为 JSON ---
try:
    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(all_data_for_milvus, f, ensure_ascii=False, indent=4)
    print(f"结果已保存到: {output_json_path}")
except Exception as e:
    print(f"错误：无法写入 JSON 文件 {output_json_path}: {e}")
# Out:
# 开始处理目录 './data/html/' 中的 HTML 文件...
# 找到 34417 个 HTML 文件。
#     警告：未能从 2018-06-13_向日葵儿童招聘啦！坐标北京 欢迎你的加入！.html 提取有效文本内容。
#     警告：未能从 2018-10-01_分享图片.html 提取有效文本内容。
#     警告：未能从 2019-01-01_分享图片.html 提取有效文本内容。
#     警告：未能从 2019-02-09_分享图片.html 提取有效文本内容。
#     警告：未能从 2020-01-24_分享图片.html 提取有效文本内容。
#     警告：未能从 2020-04-04_分享图片.html 提取有效文本内容。
#     警告：未能从 2020-08-07_我爱你，中国！.html 提取有效文本内容。
#     警告：未能从 2020-09-08_感谢有你.html 提取有效文本内容。
#     警告：未能从 2020-09-10_和你在一起！这是献给每个老师的歌.html 提取有效文本内容。
#     警告：未能从 2021-01-05_科普一下——马军教授：血液系统疾病有哪几种？.html 提取有效文本内容。
#     警告：未能从 2021-01-08_科普一下——马军教授：血液系统疾病的几大症状.html 提取有效文本内容。
#     警告：未能从 2021-01-09_科普一下——马军教授：血液系统疾病治疗要点.html 提取有效文本内容。
#     警告：未能从 2021-01-10_科普一下——马军教授：如何预防血液系统疾病.html 提取有效文本内容。
#     警告：未能从 2021-01-12_科普一下——傅卫军教授：骨髓瘤整体治疗的检测.html 提取有效文本内容。
#     警告：未能从 2021-01-13_科普一下——傅卫军教授：何为造血干细胞移植.html 提取有效文本内容。
#     警告：未能从 2021-01-15_科普一下——傅卫军教授：异基因造血干细胞移植.html 提取有效文本内容。
#     警告：未能从 2021-01-18_科普一下——傅卫军教授：骨髓瘤治疗的缓解程度.html 提取有效文本内容。
#     警告：未能从 2021-01-19_科普一下——陈文明教授：骨髓瘤诊断标准之浆细胞形态.html 提取有效文本内容。
#     警告：未能从 2021-01-20_科普一下——陈文明教授：骨髓瘤新诊断标准.html 提取有效文本内容。
#     警告：未能从 2021-01-21_科普一下——陈文明教授：骨髓瘤诊断与治疗的区别.html 提取有效文本内容。
#     警告：未能从 2021-01-25_科普一下——陈文明教授：复发难治多发性骨髓瘤的识别标.html 提取有效文本内容。
#     警告：未能从 2021-01-26_科普一下——陈文明教授：复发难治多发性骨髓瘤的药物治.html 提取有效文本内容。
#     警告：未能从 2021-01-27_科普一下——傅琤琤教授：CD19CAR-T的上市.html 提取有效文本内容。
#     警告：未能从 2021-01-28_科普一下——傅琤琤教授：国内外CAR-T药物的上市.html 提取有效文本内容。
#     警告：未能从 2021-02-01_科普一下——傅琤琤教授：骨髓瘤治疗药物进入医保的意义.html 提取有效文本内容。
#     警告：未能从 2021-02-02_科普一下——傅琤琤教授：伊沙佐米在多发性骨髓瘤中的应.html 提取有效文本内容。
#     警告：未能从 2021-02-04_科普一下——姜华教授：淋巴瘤的新药治疗进展.html 提取有效文本内容。
#     警告：未能从 2021-02-05_科普一下——姜华教授：泽布替尼和伊布替尼的异同点.html 提取有效文本内容。
#     警告：未能从 2021-02-08_科普一下——姜华教授：泽布替尼在未来淋巴瘤领域的发展.html 提取有效文本内容。
#     警告：未能从 2021-02-11_病友之家 恭祝大家新春快乐，身体健康.html 提取有效文本内容。
#     警告：未能从 2021-02-20_科普1分钟——李小秋教授：复发难治DLBCL的治疗（.html 提取有效文本内容。
#     警告：未能从 2021-02-23_科普1分钟——李小秋教授：复发难治DLBCL的治疗（.html 提取有效文本内容。
#     警告：未能从 2021-02-26_分享图片.html 提取有效文本内容。
#     警告：未能从 2021-02-27_科普1分钟——刘澎教授：淋巴瘤未来治疗趋势（上）.html 提取有效文本内容。
#     警告：未能从 2021-03-01_科普1分钟——刘澎教授：未来淋巴瘤治疗趋势（下）.html 提取有效文本内容。
#     警告：未能从 2021-03-03_科普1分钟——宋献民教授：T淋巴母细胞淋巴瘤的诊断指.html 提取有效文本内容。
#     警告：未能从 2021-03-04_大咖专访｜沈树红教授专访视频.html 提取有效文本内容。
#     警告：未能从 2021-03-04_科普1分钟——宋献民教授：T淋巴母细胞淋巴瘤的治疗进.html 提取有效文本内容。
#     警告：未能从 2021-03-05_科普1分钟——宋献民教授：HSCT在淋巴瘤治疗中的应.html 提取有效文本内容。
#     警告：未能从 2021-03-10_科普1分钟——陶荣教授：PTCL的治疗进展.html 提取有效文本内容。
#     警告：未能从 2021-03-13_科普1分钟——陶荣教授：PTCL的治疗进展（下）.html 提取有效文本内容。
#     警告：未能从 2021-03-15_科普1分钟——陶荣教授：CHOP治疗PTCL的应用前.html 提取有效文本内容。
#     警告：未能从 2021-03-16_科普1分钟——陶荣教授：CHOP治疗PTCL的应用前.html 提取有效文本内容。
#     警告：未能从 2021-03-18_科普1分钟——李军民教授：MM的治疗现状和研究进展（.html 提取有效文本内容。
#     警告：未能从 2021-03-23_大咖专访｜陈静教授谈儿童造血干细胞移植（上）.html 提取有效文本内容。
#     警告：未能从 2021-03-23_科普1分钟——李军民教授：MM的治疗现状和研究进展（.html 提取有效文本内容。
#     警告：未能从 2021-03-25_大咖专访｜陈静教授谈儿童造血干细胞移植（下）.html 提取有效文本内容。
#     警告：未能从 2021-03-26_科普1分钟——李军民教授：老年MM患者的评估和管理（.html 提取有效文本内容。
#     警告：未能从 2021-03-29_科普1分钟——李军民教授：老年MM患者的评估和管理（.html 提取有效文本内容。
#     警告：未能从 2021-03-31_大咖专访｜汤静燕教授谈儿童肾母细胞瘤的诊治进展.html 提取有效文本内容。
#     警告：未能从 2021-04-08_科普1分钟——侯健教授：多发性骨髓瘤的治疗原则.html 提取有效文本内容。
#     警告：未能从 2021-04-09_大咖专访｜胡绍燕教授谈儿童急性髓系白血病的治疗进展.html 提取有效文本内容。
#     警告：未能从 2021-04-12_科普1分钟——侯健教授：新版MM诊治指南更新内容（上.html 提取有效文本内容。
#     警告：未能从 2021-04-13_科普1分钟——侯健教授：新版MM诊治指南更新内容（下.html 提取有效文本内容。
#     警告：未能从 2021-04-16_大咖专访｜胡群教授谈血友病治疗的进展.html 提取有效文本内容。
#     警告：未能从 2021-04-23_大咖专访｜高怡瑾教授谈儿童淋巴瘤的诊疗进展（上）.html 提取有效文本内容。
#     警告：未能从 2021-04-23_科普1分钟——侯健教授：ASCT在MM中的地位不可替.html 提取有效文本内容。
#     警告：未能从 2021-04-29_科普1分钟——侯健教授：ASCT在MM中的地位不可替.html 提取有效文本内容。
#     警告：未能从 2021-04-30_大咖专访｜高怡瑾教授谈儿童淋巴瘤的诊疗进展（下）.html 提取有效文本内容。
#     警告：未能从 2021-05-01_分享图片.html 提取有效文本内容。
#     警告：未能从 2021-05-06_世界手卫生日 ｜ 我们一起好好洗手吧！.html 提取有效文本内容。
#     警告：未能从 2021-05-09_分享图片.html 提取有效文本内容。
#     警告：未能从 2021-05-10_医学时间·医路说｜了解ctDNA 检测.html 提取有效文本内容。
#     警告：未能从 2021-08-19_中国医师节｜致敬每一位生命守护者.html 提取有效文本内容。
#     警告：未能从 2021-08-21_健康科普丨管轶：新冠疫情该如何结束.html 提取有效文本内容。
#     警告：未能从 2021-09-10_教师节快乐.html 提取有效文本内容。
#     警告：未能从 2021-09-21_中秋快乐.html 提取有效文本内容。
#     警告：未能从 2021-09-30_如果世间只有一种红，那一定是中国红！.html 提取有效文本内容。
#     警告：未能从 2021-10-01_喜迎国庆｜热烈庆祝中华人民共和国成立七十二周年.html 提取有效文本内容。
#     警告：未能从 2021-10-02_一群儿白患儿的阳光唱响.html 提取有效文本内容。
#     警告：未能从 2021-12-02_新手指南1---病友经常说的那些“黑话”！.html 提取有效文本内容。
#     警告：未能从 2021-12-07_新手指南2—医生让做的检查有什么用？.html 提取有效文本内容。
#     警告：未能从 2021-12-17_2021年CSCO 白血病专家委员会巡讲-广州站.html 提取有效文本内容。
#     警告：未能从 2021-12-24_直播回放 ▏夏建川教授带你领略细胞免疫的魅力！.html 提取有效文本内容。
#     警告：未能从 2022-01-01_新年胜旧年！祝大家元旦快乐.html 提取有效文本内容。
#     警告：未能从 2022-01-31_万家灯火辞旧岁  阖家团圆迎新春.html 提取有效文本内容。
#     警告：未能从 2022-02-01_拜年红包来了！学医的人不玩套路，前一百名100%中奖.html 提取有效文本内容。
#     警告：未能从 2022-02-14_赶紧预约：2月16日1900-2000中肿翁德胜教授带你揭秘免疫细胞治疗效果！.html 提取有效文本内容。
#     警告：未能从 2022-05-01_五一劳动节快乐｜每个努力的人都值得被尊敬，致敬为梦想步履不停的你！.html 提取有效文本内容。
#     警告：未能从 2022-05-12_以爱之名，守护生命｜致天下所有白衣天使节日快乐.html 提取有效文本内容。
#     警告：未能从 2022-05-13_PICC置管后淋浴指导视频.html 提取有效文本内容。
#     警告：未能从 2022-06-01_六一儿童节｜拥有梦想的每一天都是童年 希望童真陪你成长.html 提取有效文本内容。
#     警告：未能从 2022-06-03_医路有你，端午安康.html 提取有效文本内容。
#     警告：未能从 2022-06-03_端午节｜粽叶飘香 是与家人团聚的味道.html 提取有效文本内容。
#     警告：未能从 2022-06-07_赢战高考｜金榜题名 成就梦想 全力以赴.html 提取有效文本内容。
#     警告：未能从 2022-06-28_投稿倒计时2天 ｜ 第25届全国临床肿瘤学大会暨2022年CSCO学术年会.html 提取有效文本内容。
#     警告：未能从 2022-08-19_中国医师节｜致敬每一位生命守护者.html 提取有效文本内容。
#     警告：未能从 2022-09-10_中秋节｜“ 明⽉送清辉，佳节思亲⼈”，梅斯血液新前沿邀您一起赏月！.html 提取有效文本内容。
#     警告：未能从 2022-09-10_教师节，中秋节｜谢恩师，迎中秋.html 提取有效文本内容。
#     警告：未能从 2022-10-01_喜迎国庆 ｜ 辉煌七十三载  山河锦绣灿烂.html 提取有效文本内容。
#     警告：未能从 2022-10-14_如何正确注射胰岛素.html 提取有效文本内容。
#     警告：未能从 2022-10-17_放射科CT增强检查指南七步走.html 提取有效文本内容。
#     警告：未能从 2022-10-25_会议资讯 ｜ 上海儿童医学中心国家儿童医学中心(上海)2022年《儿童肿瘤诊断治疗进展》学习班.html 提取有效文本内容。
#     警告：未能从 2022-10-28_会议资讯 ｜ “海上”儿童肿瘤“云”课堂系列之二视网膜母细胞瘤.html 提取有效文本内容。
#     警告：未能从 2022-11-10_【倒计时1天】2022 江苏省医师协会血液科医师年会暨恶性血液病精准诊疗新进展国家级继续医学教育学习班.html 提取有效文本内容。
#     警告：未能从 2022-12-08_2022抗肿瘤创新药物临床研究高峰论坛第二轮会议通知.html 提取有效文本内容。
#     警告：未能从 2023-01-01_hello2023 ｜ 新年新起点 旧岁已翻篇.html 提取有效文本内容。
#     警告：未能从 2023-01-14_冬日渐渐 小年暖暖｜喜迎小年.html 提取有效文本内容。
#     警告：未能从 2023-01-20_血液内科全体同仁恭祝大家新年快乐！.html 提取有效文本内容。
#     警告：未能从 2023-01-21_除夕快乐 ｜ 万家灯火辞旧岁 阖家团圆迎新春.html 提取有效文本内容。
#     警告：未能从 2023-01-21_除夕快乐！梅斯医学祝大家新年快乐！.html 提取有效文本内容。
#     警告：未能从 2023-01-22_【1212】大年初一，白兔捣药成，兔来送春！.html 提取有效文本内容。
#     警告：未能从 2023-01-22_初一.html 提取有效文本内容。
#     警告：未能从 2023-01-22_初一有喜｜梅斯医学给大家拜年啦！.html 提取有效文本内容。
#     警告：未能从 2023-01-23_初二.html 提取有效文本内容。
#     警告：未能从 2023-01-24_初三.html 提取有效文本内容。
#     警告：未能从 2023-01-25_初四.html 提取有效文本内容。
#     警告：未能从 2023-01-26_初五.html 提取有效文本内容。
#     警告：未能从 2023-01-26_大年初五迎财神，五路财神齐进门.html 提取有效文本内容。
#     警告：未能从 2023-01-27_初六.html 提取有效文本内容。
#     警告：未能从 2023-01-28_初七.html 提取有效文本内容。
#     警告：未能从 2023-03-08_7 成女医生认为晋升不平等，主要受生育影响，10% 遭遇职场性骚扰｜中国女医师从业报告.html 提取有效文本内容。
#     警告：未能从 2023-03-20_你知道吗？血小板只存在于哺乳动物血液中 ｜ 3.20.html 提取有效文本内容。
#     警告：未能从 2023-03-23_【通知】上海市同仁医院2023年清明节门诊安排.html 提取有效文本内容。
#     警告：未能从 2023-04-03_【通知】上海市同仁医院2023年清明节门诊安排.html 提取有效文本内容。
#     警告：未能从 2023-04-04_重要通知｜2023年清明放假通知.html 提取有效文本内容。
#     警告：未能从 2023-04-29_重要通知｜2023年五一劳动节放假通知.html 提取有效文本内容。
#     警告：未能从 2023-05-01_五一 ｜ 劳动光荣  致敬不凡.html 提取有效文本内容。
#     警告：未能从 2023-05-12_国际护士节 ｜ 致敬最美的白衣天使.html 提取有效文本内容。
#     警告：未能从 2023-05-24_【征集令】慢淋小淋临床诊疗问题，点击提问.html 提取有效文本内容。
#     警告：未能从 2023-06-01_六一儿童节 ｜ 童心未泯  快乐六一.html 提取有效文本内容。
#     警告：未能从 2023-06-06_高考加油 ｜ 挥笔行云流水  奔赴锦绣前程.html 提取有效文本内容。
#     警告：未能从 2023-06-17_端午节｜2023端午节门诊放假通知.html 提取有效文本内容。
#     警告：未能从 2023-06-22_端午节 ｜ 粽叶飘香  端午安康.html 提取有效文本内容。
#     警告：未能从 2023-09-07_警惕！血友病误诊误治怎么办？一文掌握，最全诊断要点，看完恍然大悟.......html 提取有效文本内容。
#     警告：未能从 2023-09-10_教师节 ｜ 桃李芬芳  致谢师恩.html 提取有效文本内容。
#     警告：未能从 2023-09-19_马军教授：CAR-T治疗，重燃肿瘤治愈的新希望！.html 提取有效文本内容。
#     警告：未能从 2023-09-20_通知：多发性骨髓瘤规范诊治COE24天训练营开课！.html 提取有效文本内容。
#     警告：未能从 2023-09-21_不容小觑！警惕“轻”型血友病带来的“重”磅打击.......html 提取有效文本内容。
#     警告：未能从 2023-09-25_贡铁军教授：阿基仑赛或成肿瘤的救命之药，CAR-T细胞治疗的未来之路竟少不了它…….html 提取有效文本内容。
#     警告：未能从 2023-09-27_贡铁军教授：CAR-T细胞疗法有效降低肿瘤负荷，成为提高血液肿瘤患者移植效果的关键？.html 提取有效文本内容。
#     警告：未能从 2023-09-28_刘兵城教授：TKI时代下，关于慢性病管理的“战役”该怎么打？.html 提取有效文本内容。
#     警告：未能从 2023-09-28_同仁医院“中秋+国庆”节假日门诊安排请查收！.html 提取有效文本内容。
#     警告：未能从 2023-09-29_中秋节 ｜ 皓月迎佳节  花好庆团圆.html 提取有效文本内容。
#     警告：未能从 2023-09-29_贡铁军教授：CAR-T细胞疗法-降低肿瘤负荷，一举成为提高血液肿瘤患者移植效果的关键？.html 提取有效文本内容。
#     警告：未能从 2023-09-30_郭晔教授：致力于开发创新抗肿瘤药物依旧是主流吗…….html 提取有效文本内容。
#     警告：未能从 2023-10-01_但愿人长久，健康永相伴.html 提取有效文本内容。
#     警告：未能从 2023-10-01_刘兵城教授：CML治疗方案不断优化，B细胞淋巴瘤三线治疗迎来新希望？.html 提取有效文本内容。
#     警告：未能从 2023-10-01_喜迎国庆 ｜ 盛世华诞，国泰家和.html 提取有效文本内容。
#     警告：未能从 2023-10-01_国庆节 ｜ 盛世篇章  喜迎华诞.html 提取有效文本内容。
#     警告：未能从 2023-10-02_贡铁军教授：中国血肿瘤研究取得重大突破，能否实现提前干预和生存延长？.html 提取有效文本内容。
#     警告：未能从 2023-10-03_郭晔教授：抗体药物已成为肿瘤免疫市场的主力军！.html 提取有效文本内容。
#     警告：未能从 2023-10-05_马军教授：中国血液肿瘤治疗取得突破，细胞治疗新领域的领导者竟是…….html 提取有效文本内容。
#     警告：未能从 2023-10-06_刘兵城教授：TKI靶向治疗时代，移植地位竟是这样的！.html 提取有效文本内容。
#     警告：未能从 2023-10-07_马军教授：中国肿瘤学会将成为全球肿瘤治疗的引领者？.html 提取有效文本内容。
#     警告：未能从 2023-10-08_韩冰教授：第一代C5补体抑制剂作为PNH标准治疗方案疗效显著.html 提取有效文本内容。
#     警告：未能从 2023-10-09_最后1天！多发性骨髓瘤规范诊疗COE24天训练营结课！.html 提取有效文本内容。
#     警告：未能从 2023-10-10_马军教授：聚焦新指南，血液瘤领域创新要不断…….html 提取有效文本内容。
#     警告：未能从 2023-10-12_刘兵城教授：对TKI不耐受或耐药的慢粒患者，三代TKI疗效如何？.html 提取有效文本内容。
#     警告：未能从 2023-10-13_韩冰教授：治疗PNH患者的传统方法受到多方面局限，开发新药改善疗效刻不容缓！.html 提取有效文本内容。
#     警告：未能从 2023-10-14_马军教授：关注新指南，聚焦创新药！.html 提取有效文本内容。
#     警告：未能从 2023-10-15_郭晔教授：CAR-T疗法未来进入RR DLBCL患者二线治疗还需要突破哪些障碍？.html 提取有效文本内容。
#     警告：未能从 2023-10-16_刘兵城教授：TKI时代，慢粒从药物选择到停药策略，慢病化管理是未来趋势！.html 提取有效文本内容。
#     警告：未能从 2023-10-17_韩冰教授：阵发性睡眠性血红蛋白尿症（PNH）诊疗新进展！.html 提取有效文本内容。
#     警告：未能从 2023-10-18_郭晔教授：弥漫大B细胞淋巴瘤的新药进展与探索…….html 提取有效文本内容。
#     警告：未能从 2023-10-19_马军教授：血液肿瘤领域最新进展！.html 提取有效文本内容。
#     警告：未能从 2023-10-21_贡铁军教授：CAR-T细胞治疗的未来之路！.html 提取有效文本内容。
#     警告：未能从 2023-10-22_刘兵城教授：CML患者如何选择TKI药物？.html 提取有效文本内容。
#     警告：未能从 2023-10-23_​石红霞主任：分享MPN的诊疗进展！.html 提取有效文本内容。
#     警告：未能从 2023-10-24_张曦教授：淋巴瘤的诊疗现状及其免疫治疗和新药的研究进展.html 提取有效文本内容。
#     警告：未能从 2023-10-27_胡炯教授：骨髓移植治疗白血病的临床研究现状！.html 提取有效文本内容。
#     警告：未能从 2023-10-28_张会来教授：免疫治疗再淋巴瘤中的研究进展.html 提取有效文本内容。
#     警告：未能从 2023-10-29_钱文斌教授：淋巴瘤诊疗领域最新进展！.html 提取有效文本内容。
#     警告：未能从 2023-10-30_朱军教授：弥漫性大B细胞淋巴瘤指南更新解读.html 提取有效文本内容。
#     警告：未能从 2023-10-31_重要通知：淋巴瘤规范诊疗COE25天训练营开课！.html 提取有效文本内容。
#     警告：未能从 2023-12-11_重要通知：白血病规范治疗15天训练营开课！.html 提取有效文本内容。
#     警告：未能从 2023-12-18_商务合作可扫码进行详细了解.html 提取有效文本内容。
#     警告：未能从 2023-12-29_祝全国血液科医生，新年快乐！.html 提取有效文本内容。
#     警告：未能从 2023-12-29_移植仓内生活注意事项.html 提取有效文本内容。
#     警告：未能从 2024-01-01_元旦 ｜ 新年伊始 万象更新.html 提取有效文本内容。
#     警告：未能从 2024-01-01_元旦快乐 ｜ 2024，医起向未来！.html 提取有效文本内容。
#     警告：未能从 2024-01-26_康圣环球服务中国专科特检20周年纪念封面红包限量开抢！.html 提取有效文本内容。
#     警告：未能从 2024-01-30_康圣环球服务中国专科特检20周年纪念封面红包限量开抢！.html 提取有效文本内容。
#     警告：未能从 2024-01-31_康圣环球服务中国专科特检20周年纪念封面红包限量开抢！.html 提取有效文本内容。
#     警告：未能从 2024-02-02_康圣环球服务中国专科特检20周年纪念封面红包限量开抢！.html 提取有效文本内容。
#     警告：未能从 2024-02-05_康圣环球服务中国专科特检20周年纪念封面红包限量开抢！.html 提取有效文本内容。
#     警告：未能从 2024-02-07_康圣环球服务中国专科特检20周年纪念封面红包限量开抢！.html 提取有效文本内容。
#     警告：未能从 2024-02-09_康圣环球服务中国专科特检20周年纪念封面红包限量开抢！.html 提取有效文本内容。
#     警告：未能从 2024-02-14_喜迎财神 ｜ 初五拜财神，五路财神迎进门.html 提取有效文本内容。
#     警告：未能从 2024-04-25_预防跌倒坠床健康宣教视频.html 提取有效文本内容。
#     警告：未能从 2024-04-27_放假通知｜点击查收：劳动节假期门诊安排.html 提取有效文本内容。
#     警告：未能从 2024-05-30_【1599】诺华旗下多款产品亮相第29届欧洲血液学协会年会.html 提取有效文本内容。
#     警告：未能从 2024-06-04_互联网护理服务预约流程.html 提取有效文本内容。
#     警告：未能从 2024-06-08_端午节｜预祝大家2024年端午安康.html 提取有效文本内容。
#     警告：未能从 2024-06-16_最新花絮！梅斯医学现场报道2024血液与再生医学大会.html 提取有效文本内容。
#     警告：未能从 2024-08-17_瑞金医院造血干细胞移植中心扩容三周年宣传片.html 提取有效文本内容。
#     警告：未能从 2024-09-04_世界白血病日 ｜ 我们正与全球血液病专家一起攻克白血.html 提取有效文本内容。
#     警告：未能从 2024-09-12_【9月14日】世界淋巴瘤日直播预告 ｜ 中国首份边缘区淋巴瘤白皮书发布会.html 提取有效文本内容。
#     警告：未能从 2024-09-17_欢度中秋 ｜ 共赏圆月一轮，喜迎中秋良宵.html 提取有效文本内容。
#     警告：未能从 2024-09-28_国诞喜乐｜国庆假期移植专科门诊安排.html 提取有效文本内容。
#     警告：未能从 2024-10-01_欢度国庆 ｜ 展望祖国新貌，描绘美好未来.html 提取有效文本内容。
#     警告：未能从 2024-10-01_盛世华诞，共谱华章.html 提取有效文本内容。
#     警告：未能从 2024-10-15_造血干细胞移植中心家属送餐流程.html 提取有效文本内容。
#
# 处理完成。共处理 34417 个文件，生成 29143 个文本块。
# 结果已保存到: ./data/processed_data.json
